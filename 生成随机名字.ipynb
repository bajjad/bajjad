# %%
# 生成随机姓名

firstName = [
    '丁', '万', '严', '乔', '习', '于', '付', '代', '任', '何', '余', '佟', '侯', '俞', '傅', 
    '元', '关', '冯', '刘', '包', '华', '单', '卢', '卫', '史', '叶', '吉', '向', '吕', '费',
    '吴', '周', '唐', '喻', '夏', '奚', '姚', '姜', '孔', '孙', '孟', '安', '宋', '丘', '殷',
    '宫', '尹', '岑', '崔', '嵇', '左', '常', '庄', '庞', '康', '廖', '张', '彭', '云', '刀',
    '徐', '恩', '惠', '戚', '戴', '房', '方', '施', '曹', '曾', '朱', '李', '杜', '束', '来', 
    '杨', '林', '柏', '柯', '栗', '梁', '楚', '樊', '步', '武', '段', '毛', '江', '汤', '茹',
    '汪', '沈', '洪', '涂', '潘', '焦', '熊', '王', '甄', '甘', '田', '白', '石', '礼', '祝', 
    '秦', '程', '窦', '章', '简', '纪', '练', '罗', '翟', '聂', '肖', '胡', '花', '苏', '苗', 
    '范', '荣', '莫', '萧', '葛', '董', '蒋', '蓝', '蔡', '薛', '虞', '袁', '褚', '覃', '许', 
    '谢', '谭', '谷', '贺', '贾', '赵', '车', '邓', '邢', '邰', '邱', '邵', '邹', '郎', '姬',
    '郑', '郝', '郭', '金', '钟', '钱', '阎', '陆', '陈', '陶', '雷', '韦', '韩', '顾', '马', 
    '高', '魏', '黄', '黎', '龙', '龚', '古', '柳', '李', '王', '张', '赵', '周', '吴', '马',
    '令狐', '司马', '完颜', '欧阳', '诸葛', '慕容'
]

middleName = [
    '丽', '秋', '现', '勇', '竹', '俊', '自', '宏', '以', '利', '立', '冠', '若', '华', '建', 
    '贯', '国', '朝', '元', '芷', '处', '冬', '财', '鸿', '耿', '叶', '新', '青', '钰',
    '延', '凡', '卫', '耀', '尚', '梓', '近', '佳', '白', '顺', '明', '昭', '景', '田', 
    '正', '大', '昌', '雷', '莉', '坚', '英', '崇', '理', '向', '忠', '祥', '长', '依', '君', 
    '东', '晓', '金', '爱', '卓', '学', '暖', '吉', '珊', '光', '怀', '浩', '乃', '雪', '紫',
    '凤', '堂', '宁', '文', '嘉', '岩', '玉', '亚', '莉', '汝', '庆', '杰', '雅', '慧', 
    '广', '宝', '星', '虎', '婷', '天', '泽', '家', '为', '仲', '淑', '莎', '阿', '月', '永', 
    '道', '克', '绍', '世', '黎', '豫', '瑞', '小', '彩', '时', '胜', '程', '兴', '雨', '丹',
    '素', '行', '贵', '臣', '军', '海', '艳', '汉', '继', '旭', '清', '兆', '震', '振', '玄',
    '云', '书', '德', '生', '宣', '百', '士', '跃', '成', '志', '曙', '颖', '京', '春', '方', 
    '续', '连', '伟', '兰', '南', '少', '红', '飞', '别', '达', '人', '好', '羽', '鑫', '致',
    '本', '中'
]

lastName = [
    '亮', '均', '灵', '丽', '健', '凯', '剑', '龙', '钧', '威', '轩', '袆', '豪', '凡', '博',
    '松', '勇', '用', '昂', '蔓', '源', '梅', '之', '靖', '宏', '利', '茂', '华', '乐', '兰',
    '建', '冲', '熹', '航', '国', '蕾', '枫', '声', '有', '英', '缇', '坤', '舒', '藻', '德', 
    '哲', '斌', '林', '鸿', '楠', '淼', '新', '洛', '荣', '霖', '彪', '妹', '耀', '卫', '茜', 
    '远', '涛', '强', '翠', '姝', '迪', '明', '田', '昌', '莉', '坚', '理', '皓', '忠', '衣',
    '祥', '蓉', '君', '东', '巍', '锋', '金', '琳', '纲', '雄', '仁', '隽', '岭', '安', '盛', 
    '睿', '菊', '筱', '蕊', '年', '蕙', '珊', '光', '权', '浩', '曈', '彬', '函', '初', '玲', 
    '超', '劳', '庸', '炜', '雪', '刚', '鹏', '侠', '宁', '峰', '文', '康', '岚', '佐', '龄',
    '玉', '卿', '洁', '骅', '岩', '开', '问', '萍', '娟', '硕', '磊', '南', '庆', '杰', '霞', 
    '惠', '兵', '宇', '楚', '雁', '欣', '宝', '广', '娜', '良', '婷', '恒', '咏', '倩', '臣',
    '若', '永', '森', '瑞', '凌', '艺', '鹤', '水', '瑶', '香', '胜', '桦', '竹', '静', '冰', 
    '爽', '军', '奇', '海', '艳', '燕', '辉', '清', '兆', '震', '红', '机', '阳', '莹', '云', 
    '聪', '琴', '娴', '民', '生', '江', '泉', '莎', '洲', '欢', '飞', '跃', '成', '会', '山', 
    '志', '勋', '晴', '平', '春', '中', '怡', '伟', '敏', '丰', '青', '鑫', '波', '鲜', '复',
    '芹', '素', '韫', '菲', '英', '平', '淳', '熙', '烈', '秀', '鸿', '白', '甫', '翔', '凤',
    '妮', '河'
]

girl = [
    '艺', '薇', '曼', '君', '瑜', '思', '欢', '萱', '霭', '月', '诗', '梅', '婵', '荣', '笑', 
    '莉', '柏', '莎', '澜', '凝', '黛', '颖', '越', '宜', '梦', '桂', '叶', '晶', '雯', '懿',
    '欣', '馥', '凤', '嫣', '明', '香', '珠', '仪', '春', '竹', '逸', '彤', '姗', '珊', '贞', 
    '鑫', '睿', '冰', '婕', '艳', '娅', '琬', '莲', '琳', '珍', '文', '筠', '涛', '青', '舒',
    '红', '凡', '璐', '静', '爽', '瑾', '琰', '志', '云', '婉', '霞', '秀', '熙', '丹', '娜',
    '蓉', '晓', '茜', '羽', '楷', '雁', '妍', '娥', '黎', '蕙', '致', '丽', '咏', '巧', '皓', 
    '凌', '瑗', '彩', '风', '瑶', '悦', '歆', '美', '健', '可', '纨', '霖', '宁', '爱', '枫', 
    '敏', '依', '智', '晋', '洁', '枝', '寒', '菁', '俊', '淑', '语', '华', '娴', '祺', '雪',
    '姿', '优', '芙', '瑞', '莺', '秋', '雅', '卿', '柔', '慧', '曦', '园', '希', '鸿', '天',
    '芝', '韵', '婧', '露', '玲', '岚', '檀', '玥', '远', '璇', '菊', '聪', '馨', '蓓', '兰',
    '飘', '彬', '楠', '超', '娟', '昕', '亚', '茹', '芬', '蕊', '祎', '真', '修', '珺', '菲',
    '靖', '萍', '翠', '妹', '璧', '茗', '怡', '伊', '琪', '涵', '然', '滢', '素', '芳', '倩',
    '璟', '妮', '洋', '若', '眉', '融', '苑', '嫦', '灵', '媛', '荷', '钰', '影', '芸', '琦',
    '嘉', '茵', '卉', '姣', '星', '娣', '佳', '雨', '琼', '瀚', '乐', '勤', '英', '荔', '婷',
    '子', '榆', '漫', '惠', '燕', '碧', '琴', '立', '泽', '玉', '奇', '初', '莹'   
]

boy = [
    '行', '晨', '维', '兴', '鹏', '松', '进', '翔', '政', '有', '思', '厚', '斌', '江', '琛', 
    '力', '功', '泰', '辉', '明', '祥', '伯', '时', '群', '冠', '东', '言', '刚', '波', '飞', 
    '绍', '亨', '心', '文', '裕', '谦', '涛', '杰', '哲', '龙', '安', '山', '信', '固', '志', 
    '武', '富', '茂', '生', '邦', '善', '致', '榕', '风', '坚', '河', '钧', '健', '彪', '震', 
    '宁', '军', '才', '顺', '旭', '家', '弘', '士', '毅', '清', '树', '达', '全', '俊', '利', 
    '仁', '福', '梁', '磊', '先', '会', '轮', '友', '平', '强', '成', '康', '振', '栋', '建', 
    '彬', '超', '伦', '楠', '承', '德', '鸣', '之', '伟', '策', '以', '勇', '壮', '朋', '宏', 
    '永', '发', '光', '岩', '庆', '义', '博', '亮', '广', '国', '克', '若', '昌', '新', '雄', 
    '朗', '良', '星', '林', '贵', '胜', '诚', '敬', '翰', '保', '乐', '腾', '元', '豪', '峰', 
    '航', '子', '学', '泽', '民', '奇', '海', '世', '启', '天', '中', '炎', '盛', '和', '浩', 
    '辰', '轩', '昂', '曈', '驰', '凯'
]

def random_name(n):
    import random
    
    d = {}
    sex = [0,1,1]
    
    for i in range(n):

        # 生成 姓
        fn = random.choice(firstName)

        s = random.choice(sex)

        mn = random.choice(middleName)

        if s: # 男性
            #mn = random.choice(boy)
            ln = random.choice(boy)
        else: # 女性
            #mn = random.choice(girl)
            ln = random.choice(girl)

        if random.randint(1,3) == 1:
            mn = ''

        # 生成 名字
        name = fn + mn + ln
        
        d[name] = ['男' if s else '女'][0]

    return d

def find_name(n):
    if not n:
        print('输入错误')
        return -1
    
    if n[0] not in firstName:
        print('n0=', n[0])
        return 1
    
    if n[-1] not in girl and n[-1] not in boy:
        print('n-1=', n[-1])
        return 3
    
    if len(n) == 3 and (n[1] not in girl and n[1] not in boy):
        print('n1=', n[1])
        return 2
    
    return 0

# names = [ random_name() for i in range(100) ]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()

# %%
df['姓名'] = names

# %%
df
# Out:
#      姓名
# 0   谷财言
# 1   吴梓辰
# 2   单华荔
# 3   龚雷亮
# 4   甘素玲
# ..  ...
# 95  邱德辉
# 96   覃时
# 97   武博
# 98  汤海世
# 99   甘晨
#
# [100 rows x 1 columns]

# %%
df.query('性别=="女"')
# Out:
#       姓名 性别
# 0     李彩  女
# 10    云卿  女
# 11   阎彩枫  女
# 15   马芷洁  女
# 17   虞志逸  女
# ..   ... ..
# 315  袁尚凝  女
# 320  欧阳爱  女
# 323   武钰  女
# 327   姬寒  女
# 330  谷兆瑗  女
#
# [106 rows x 2 columns]

# %%
nianji = [13 for i in range(112)]

# %%
nianji1 = [14 for i in range(112)]

# %%
nianji2 = [15 for i in range(112)]

# %%
nj1 = nianji + nianji1 + nianji2

# %%
nj2 = nianji + nianji1 + nianji2

# %%
nj3 = nianji + nianji1 + nianji2

# %%
nj = nj1 + nj2 + nj3

# %%
len(nj1)
# Out:
# 336

# %%
df['年龄'] = nj1

# %%
df
# Out:
#           学号    姓名 性别   身高    体重  年级  班级   语文   数学   英语  物理  化学  年龄
# 0    1496701    李彩  女  179  82.0  初一  一班   67   73   51  70  54  13
# 1    1401411   彭紫琛  男  154  46.3  初一  一班  116   83  150  36  39  13
# 2    1330117  慕容小勇  男  184  46.9  初一  一班  113  150  133  95  75  13
# 3    1698402   常飞东  男  165  68.2  初一  一班  117   38  150  84  71  13
# 4    1588828   关别善  男  158  58.6  初一  一班  117   96   84  26  62  13
# ..       ...   ... ..  ...   ...  ..  ..  ...  ...  ...  ..  ..  ..
# 331  1723057    涂士  男  189  59.6  初三  四班   86   56   92  64  26  15
# 332  1164485    徐致  男  173  46.7  初三  四班  126   96  133  59  31  15
# 333  1162831   张时树  男  174  57.7  初三  四班  144   93   51  40  74  15
# 334  1318688    顾安  男  186  52.4  初三  四班  131   85   93  22  84  15
# 335  1453151   韦为榕  男  181  51.4  初三  四班  116   50  136  84  72  15
#
# [336 rows x 13 columns]

# %%
df.query('年级=="初一" & 班级=="二班" & 性别=="女"')
# Out:
#       姓名 性别  年级  班级   语文   数学   英语  物理  化学   身高    体重
# 29   令狐春  女  初一  二班  125   67   85  28  32  183  85.8
# 31    俞乐  女  初一  二班  115  140   72  83  93  171  76.6
# 40    苗秋  女  初一  二班   83  127  148  35  68  154  58.4
# 42    蒋子  女  初一  二班   99   86   60  88  24  164  84.9
# 43   史昭楷  女  初一  二班  131  101   65  65  33  182  86.2
# 46   甘梓香  女  初一  二班   74  102  103  40  74  186  50.4
# 48  令狐新璇  女  初一  二班  138   49   91  96  88  165  64.0
# 50    郝黎  女  初一  二班   90   66   75  61  44  164  86.4
# 51   罗白梦  女  初一  二班  147   32   83  44  52  170  46.8
# 52   慕容晋  女  初一  二班  125   74  135  34  61  190  84.6
# 53   沈杰莹  女  初一  二班  111   51   74  76  43  154  76.1
# 54   柯本娜  女  初一  二班   69   70  127  19  81  169  79.9

# %%
from random import randint, uniform

blood = ['A','B','AB','O']
yuwen = [ blood[randint(0,3)] for i in range(336)]

# %%
df['血型'] = yuwen

# %%
df.to_excel("/users/liqiang/desktop/学生成绩报表-new.xlsx",index=False)

# %%
df = pd.read_excel("/users/liqiang/desktop/学生成绩报表-new.xlsx",index=False)

# %%
df
# Out:
#           学号    姓名 性别   身高    体重  年级  班级   语文   数学   英语  物理  化学  年龄  血型
# 0    1496701    李彩  女  179  82.0  初一  一班   67   73   51  70  54  13   O
# 1    1401411   彭紫琛  男  154  46.3  初一  一班  116   83  150  36  39  13  AB
# 2    1330117  慕容小勇  男  184  46.9  初一  一班  113  150  133  95  75  13   B
# 3    1698402   常飞东  男  165  68.2  初一  一班  117   38  150  84  71  13   B
# 4    1588828   关别善  男  158  58.6  初一  一班  117   96   84  26  62  13   O
# ..       ...   ... ..  ...   ...  ..  ..  ...  ...  ...  ..  ..  ..  ..
# 331  1723057    涂士  男  189  59.6  初三  四班   86   56   92  64  26  15   A
# 332  1164485    徐致  男  173  46.7  初三  四班  126   96  133  59  31  15   O
# 333  1162831   张时树  男  174  57.7  初三  四班  144   93   51  40  74  15  AB
# 334  1318688    顾安  男  186  52.4  初三  四班  131   85   93  22  84  15   A
# 335  1453151   韦为榕  男  181  51.4  初三  四班  116   50  136  84  72  15   B
#
# [336 rows x 14 columns]

# %%
df.query('语文 > 120 & 数学 > 120 & 英语 > 120 & 物理 > 90 & 化学 > 90')
# Out:
#           学号  姓名 性别   身高    体重  年级  班级   语文   数学   英语   物理   化学
# 216  1276315  马坚  男  188  41.6  初二  四班  122  149  135  100  100

# %%
df
# Out:
#           学号    姓名 性别   身高    体重  年级  班级   语文   数学   英语  物理  化学  年龄
# 0    1496701    李彩  女  179  82.0  初一  一班   67   73   51  70  54  13
# 1    1401411   彭紫琛  男  154  46.3  初一  一班  116   83  150  36  39  13
# 2    1330117  慕容小勇  男  184  46.9  初一  一班  113  150  133  95  75  13
# 3    1698402   常飞东  男  165  68.2  初一  一班  117   38  150  84  71  13
# 4    1588828   关别善  男  158  58.6  初一  一班  117   96   84  26  62  13
# ..       ...   ... ..  ...   ...  ..  ..  ...  ...  ...  ..  ..  ..
# 331  1723057    涂士  男  189  59.6  初三  四班   86   56   92  64  26  15
# 332  1164485    徐致  男  173  46.7  初三  四班  126   96  133  59  31  15
# 333  1162831   张时树  男  174  57.7  初三  四班  144   93   51  40  74  15
# 334  1318688    顾安  男  186  52.4  初三  四班  131   85   93  22  84  15
# 335  1453151   韦为榕  男  181  51.4  初三  四班  116   50  136  84  72  15
#
# [336 rows x 13 columns]

# %%
df1 = df.loc[:, ['学号','姓名','性别','年龄','血型','身高','体重']]

# %%
df1.to_excel("/users/liqiang/desktop/学生基本信息表.xlsx", index=False)

# %%
df1.groupby(['年龄','性别']).size()
# Out:
# 年龄  性别
# 13  女     38
#     男     74
# 14  女     31
#     男     81
# 15  女     37
#     男     75
# dtype: int64

# %%
df1.groupby(['年龄','性别']).size().reset_index(name='counts')
# Out:
#    年龄 性别  counts
# 0  13  女      38
# 1  13  男      74
# 2  14  女      31
# 3  14  男      81
# 4  15  女      37
# 5  15  男      75

# %%
df.groupby(['年级','班级','性别']).size().reset_index(name='小计')
# Out:
#     年级  班级 性别  小计
# 0   初一  一班  女   8
# 1   初一  一班  男  20
# 2   初一  三班  女   8
# 3   初一  三班  男  20
# 4   初一  二班  女  12
# 5   初一  二班  男  16
# 6   初一  四班  女  10
# 7   初一  四班  男  18
# 8   初三  一班  女   7
# 9   初三  一班  男  21
# 10  初三  三班  女  11
# 11  初三  三班  男  17
# 12  初三  二班  女  12
# 13  初三  二班  男  16
# 14  初三  四班  女   7
# 15  初三  四班  男  21
# 16  初二  一班  女   7
# 17  初二  一班  男  21
# 18  初二  三班  女   7
# 19  初二  三班  男  21
# 20  初二  二班  女   8
# 21  初二  二班  男  20
# 22  初二  四班  女   9
# 23  初二  四班  男  19

# %%
dd = random_name(100)

# %%
dd
# Out:
# {'乔飞亮': '男',
#  '苏绍岩': '男',
#  '陶婷娟': '女',
#  '虞暖雁': '女',
#  '罗宜': '女',
#  '丁琳': '女',
#  '岑伦': '男',
#  '郝春卿': '女',
#  '岑臣秋': '女',
#  '阎卫莎': '女'}

# %%
df = pd.DataFrame(list(dd.items()), columns=['姓名','性别'], index=[x for x in range(1,len(dd)+1)])

# %%
df[df['性别'].str.contains('女')]
# Out:
#      姓名 性别
# 8    江可  女
# 11   张嫣  女
# 17  褚重慧  女
# 18  向凤依  女
# 19  纪跃玲  女
# 25  韦月靖  女
# 26  朱家嫣  女
# 28  韦彩子  女
# 31  楚建懿  女
# 32  曾贵妮  女
# 35  邹乃璧  女
# 36  曹震乐  女
# 41   练嫦  女
# 42  费向丽  女
# 43   崔飘  女
# 46  刀光伊  女
# 56  聂浩凡  女
# 59  柯黎芳  女
# 60  黄雪荣  女
# 66  彭别贞  女
# 72  何白馥  女
# 73   雷凝  女
# 77   来春  女
# 79   莫馥  女
# 83   潘卿  女
# 86   贺枝  女
# 90  华行茹  女
# 92  邰中梦  女
# 93  岑芷真  女
# 95  周丹芸  女
# 98  朱宝彬  女

# %%
from random import randint,uniform

df['BMI'] = df['体重'] / (df['身高'] / 100) ** 2

# %%
df.groupby(['性别']).size().reset_index(name='小计')
# Out:
#   性别  小计
# 0  女  31
# 1  男  69

# %%
df.groupby('血型').size().reset_index(name='小计')
# Out:
#    血型  小计
# 0   A  18
# 1  AB  26
# 2   B  28
# 3   O  28

# %%
df.shape
# Out:
# (100, 5)

# %%
df
# Out:
#       姓名 性别  血型   身高    体重
# 1     柏博  男  AB  171  86.1
# 2    步飞斌  男   O  155  51.6
# 3    马财奇  男   O  154  75.2
# 4     江林  男   A  157  63.1
# 5    丘钰钧  男  AB  157  86.3
# ..   ... ..  ..  ...   ...
# 96   花清东  男   O  182  63.3
# 97   邓兴维  男  AB  179  61.0
# 98   朱宝彬  女   O  190  64.7
# 99   窦新厚  男   O  182  69.9
# 100   朱友  男  AB  183  63.5
#
# [100 rows x 5 columns]

# %%
df['BMI'] = round(df['体重'] / (df['身高'] / 100) ** 2,1)

# %%
df
# Out:
#       姓名 性别  血型   身高    体重   BMI
# 1     柏博  男  AB  171  86.1  29.4
# 2    步飞斌  男   O  155  51.6  21.5
# 3    马财奇  男   O  154  75.2  31.7
# 4     江林  男   A  157  63.1  25.6
# 5    丘钰钧  男  AB  157  86.3  35.0
# ..   ... ..  ..  ...   ...   ...
# 96   花清东  男   O  182  63.3  19.1
# 97   邓兴维  男  AB  179  61.0  19.0
# 98   朱宝彬  女   O  190  64.7  17.9
# 99   窦新厚  男   O  182  69.9  21.1
# 100   朱友  男  AB  183  63.5  19.0
#
# [100 rows x 6 columns]

# %%
df['学号'] = [randint(1000000,3000000) for i in range(df.shape[0])]

# %%
df
# Out:
#       姓名 性别  血型   身高    体重   BMI       学号
# 1     柏博  男  AB  171  86.1  29.4  2333152
# 2    步飞斌  男   O  155  51.6  21.5  2604464
# 3    马财奇  男   O  154  75.2  31.7  2236453
# 4     江林  男   A  157  63.1  25.6  2901052
# 5    丘钰钧  男  AB  157  86.3  35.0  1537692
# ..   ... ..  ..  ...   ...   ...      ...
# 96   花清东  男   O  182  63.3  19.1  2273199
# 97   邓兴维  男  AB  179  61.0  19.0  1891275
# 98   朱宝彬  女   O  190  64.7  17.9  2436227
# 99   窦新厚  男   O  182  69.9  21.1  1856133
# 100   朱友  男  AB  183  63.5  19.0  1501847
#
# [100 rows x 7 columns]

# %%
df1 = df[['学号','姓名','性别','血型','身高','体重','BMI']]

# %%
df = df1

# %%
df
# Out:
#           学号   姓名 性别  血型   身高    体重   BMI
# 1    2333152   柏博  男  AB  171  86.1  29.4
# 2    2604464  步飞斌  男   O  155  51.6  21.5
# 3    2236453  马财奇  男   O  154  75.2  31.7
# 4    2901052   江林  男   A  157  63.1  25.6
# 5    1537692  丘钰钧  男  AB  157  86.3  35.0
# ..       ...  ... ..  ..  ...   ...   ...
# 96   2273199  花清东  男   O  182  63.3  19.1
# 97   1891275  邓兴维  男  AB  179  61.0  19.0
# 98   2436227  朱宝彬  女   O  190  64.7  17.9
# 99   1856133  窦新厚  男   O  182  69.9  21.1
# 100  1501847   朱友  男  AB  183  63.5  19.0
#
# [100 rows x 7 columns]

# %%
df.to_excel("/users/liqiang/desktop/data/学生基本情况表.xlsx", index=False)

# %%
df[df['姓名'].str.contains('李|王|邓')]
# Out:
#          学号   姓名 性别  血型   身高    体重   BMI
# 12  1884244  李现山  男  AB  168  65.5  23.2
# 13  1850101   邓启  男   B  157  74.8  30.3
# 38  1341123   王飞  男   A  178  82.6  26.1
# 50  1629166  李伟良  男   A  167  83.2  29.8
# 62  2185343   王行  男   O  159  84.2  33.3
# 97  1891275  邓兴维  男  AB  179  61.0  19.0

# %%
df[df['BMI'] < 18.5]
# Out:
#          学号   姓名 性别  血型   身高    体重   BMI
# 6   1112785  吴现文  男   B  167  47.8  17.1
# 11  1196396   张嫣  女   B  185  52.5  15.3
# 17  2833208  褚重慧  女   B  186  46.2  13.4
# 18  1683565  向凤依  女   O  158  44.6  17.9
# 21  1716772   包鹏  男   B  187  51.7  14.8
# 23  1014059  雷正曈  男   B  180  54.3  16.8
# 31  1444387  楚建懿  女   O  160  46.9  18.3
# 34  1900057  刀乃发  男  AB  189  61.8  17.3
# 36  1544842  曹震乐  女   B  180  56.9  17.6
# 37  1164239  周耿良  男   A  175  51.5  16.8
# 66  2923470  彭别贞  女   A  166  46.8  17.0
# 67  2770266  严月清  男   A  188  64.9  18.4
# 68  1200499  姚克斌  男   O  190  62.1  17.2
# 72  2906108  何白馥  女   O  172  44.0  14.9
# 74  1134890  郭云进  男   A  190  54.5  15.1
# 77  1723880   来春  女   O  184  44.6  13.2
# 82  1146978   单盛  男   B  184  51.9  15.3
# 84  1191968  花天和  男   O  166  50.3  18.3
# 85  1139116  郭绍岩  男  AB  181  46.6  14.2
# 89  2537892  林云保  男   O  169  46.4  16.2
# 90  1727154  华行茹  女  AB  183  43.7  13.0
# 91  2225266  阎玄贵  男   B  184  59.6  17.6
# ...

# %%
df.iloc[[1,5]]
# Out:
#         学号   姓名 性别 血型   身高    体重   BMI
# 2  2604464  步飞斌  男  O  155  51.6  21.5
# 6  1112785  吴现文  男  B  167  47.8  17.1

# %%
import matplotlib.pyplot as plt

# %%
df['身高'].plot(kind="bar")

# %%
df['体重'].plot()

# %%
df[['姓名','性别','体重']][:10]
# Out:
#      姓名 性别    体重
# 1    柏博  男  86.1
# 2   步飞斌  男  51.6
# 3   马财奇  男  75.2
# 4    江林  男  63.1
# 5   丘钰钧  男  86.3
# 6   吴现文  男  47.8
# 7   俞祥裕  男  60.0
# 8    江可  女  80.5
# 9   甄继东  男  76.2
# 10  来为敬  男  73.8

# %%
df['体重'].plot(kind="bar")

# %%
df[20:30].groupby('性别').size().reset_index(name='小计').plot(kind="bar")

# %%
import numpy as np

# %%
np.eye(3,3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.random.rand(3,3)
# Out:
# array([[0.16245687, 0.28160883, 0.53865363],
#        [0.43089736, 0.18620058, 0.96903175],
#        [0.49478359, 0.7838456 , 0.46453003]])

# %%
doubanf = pd.read_csv("/users/liqiang/desktop/data/豆瓣华语电影数据处理后.csv")

# %%
doubanf.columns
# Out:
# Index(['actor', 'date', 'director', 'id', 'language', 'rate', 'rating_num',
#        'region', 'runtime', 'title', 'type', 'year', 'is_cn', 'is_hk', 'is_tw',
#        'is_drama', 'is_comedy', 'is_action', 'is_romance', 'is_scifi',
#        'is_cartoon', 'is_mystery', 'is_thriller', 'is_horror', 'is_crime',
#        'is_homosexua', 'is_music', 'is_musical', 'is_biographical',
#        'is_historical', 'is_war', 'is_western', 'is_fantasy', 'is_adventure',
#        'is_disaster', 'is_sowordsmen', 'is_erotic', 'is_best', 'is_worst'],
#       dtype='object')

# %%
doubanf[doubanf['rate']>9][['title','date','director','actor','rate']]
# Out:
#                          title  \
# 90                          茶馆
# 102                    背靠背，脸对脸
# 191                       鬼子来了
# 198                         活着
# 251      大话西游之大圣娶亲 西遊記大結局之仙履奇緣
# 252                       霸王别姬
# 283                       大闹天宫
# 555                       天堂回信
# 731                        剃头匠
# 809                       哀乐中年
# 852                    遥望南方的童年
# 1097             狐妖小红娘剧场版：王权富贵
# 1112              狐妖小红娘剧场版：月红篇
# 1289                      红日风暴
# 1481                   极限公益联欢会
# 1804                       齐天乐
# 2692                      丝路花雨
# 5768                   无间道 無間道
# 6656   黄子华栋笃笑之金盘𠺘口 黄子华栋笃笑之金盆啷口
# 6731                       紫钗记
# 7160               蝶影红梨记 蝶影紅梨記
# 10912                饮食男女 飲食男女
# 11053                  老子说 老子說
# 13485                    南海十三郎
# 13551       跟住去边度 黃子華栋笃笑之跟住去邊度
#
#                                                     date  \
# 90                                              ['1982']
# ...

# %%
doubanf[doubanf['actor'].str.contains("朱茵")][['title','date','director','actor','rate']]
# Out:
#                           title  \
# 108                        越光宝盒
# 216    大话西游之月光宝盒 西遊記第壹佰零壹回之月光寶盒
# 251       大话西游之大圣娶亲 西遊記大結局之仙履奇緣
# 293                        天下无双
# 322                         云水谣
# 1102                       二次初恋
# 1713                         嘿店
# 2150                     芳香之城传奇
# 5059                       感光时代
# 5448                       一墙之隔
# 5859                逃学威龙2 逃學威龍2
# 5950                    O记三合会档案
# 6017                     赌侠1999
# 6052                  臭屁王 蠟筆小小生
# 6316                       中华赌侠
# 6335                       的士判官
# 6393                  逃学外传 逃學外傳
# 6462                 求爱上上签 性感都市
# 6501                      一屋哨牙鬼
# 7002                         心寒
# 7021            夜半无人尸语时 夜半無人屍語時
# 7036                     超级整蛊霸王
# 7234                    生命揸fit人
# 7294                       风尘三侠
# 7368                       2人三足
# 7583                   缘份有TAKE2
# 7688              重庆爱情感觉 重慶愛情感覺
# 7733                  超级女警 狂凤密令
# ...
