# %%
# Python正则表达式

regex = """
        .         - Any Character Except New Line       - 任意字符
        \d        - Digit (0-9)                         - 数字
        \D        - Not a Digit (0-9)                   - 非数字
        \w        - Word Character (a-z, A-Z, 0-9, _)   - 字符
        \W        - Not a Word Character                - 非字符
        \s        - Whitespace (space, tab, newline)    - 空白字符
        \S        - Not Whitespace                      - 非空白字符
        \b        - Word Boundary                       - 单词边界
        []        - To indicate a set of characters.    - 表示一组字符a或b或c
        {m,n}     - repetitions of the preceding        - 匹配前面 RE 的 m 到 n 次重复
        {m}       - repeate m times.                    - 重复匹配m次
        
"""

text_to_search = """
abc defghijklmnopqrstuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890

Ha HaHa

MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )

coreyms.com

321-551-4321
+356 9964 7107
+86 13601267090
135-2075-0008

Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. Li

完结篇 大象学术译丛第十二弹《史学原论》.azw3
摇落的风情——第一奇书《金瓶梅》绎解---卜键.azw3
中亚正版《战争总动员：美国二战国内史 (图史系列)》.azw3
i-book.in__《JavaScript之美》.pdf
完结篇 大象学术译丛第十二弹《1984》.azw3
"""

sentence = 'Start a sentence and then bring it to an end.'

# %%
# Python re 代码

import re

# 取书名号中间的内容，返回起止位置在.start()和.end()中，可在.group()中取得内容
# pattern = re.compile(r'《.+》')

# 取电话号码
# pattern = re.compile(r'[+|+\d]{0,3}[\d|\-| ]{3,}')

pattern = re.compile(r'7090\Z')

matches = pattern.finditer(text_to_search)

for match in matches:
    
    """
    适用于电话号码
    过滤返回串长度小于5的，可能不是电话号码
    if len(match.group()) < 5:
        continue
    """
    
    print(match)
    
    
    # 通过start和end在原始串中去内容
    # print(text_to_search[match.start()+1:match.end()-1])
    
    # 通过group截去头尾取内容
    # print(match.group()[1:-1])
    
    print(match.group())
