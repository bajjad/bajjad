# %% [markdown]
# ## matplotlib中文处理

# %% [markdown]
# ### 常用库

# %%
# 常用库
import pandas as pd
import numpy as np

# %%
# 删除并重装matplotlib
# 未执行，留用

# !sudo apt-get remove python3-matplotlib
# !sudo pip3 install matplotlib

# %%
# !/opt/anaconda3/bin/python3 -m pip install --upgrade pip

# %%
# 安装维基百科库
# !pip install wikipedia
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11686 sha256=cdd9780f9425d47a391379ec2d14569b5f91e885f94077e995c4f17d3b7c888d
#   Stored in directory: /Users/liqiang/Library/Caches/pip/wheels/ac/aa/6d/d1ccbcaa1fac41fed8ef1d32f7b3f145c054b607cc7a28bda3
# Successfully built wikipedia
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python3 -m pip install --upgrade pip' command.

# %%
# 显示matplotlib版本
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.1.1

# %%
# 查看已安装的字体
import matplotlib.font_manager
for i in matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf'):
    if 'simhei' in i.lower():
        print(i)
# Out:
# /Users/liqiang/Library/Fonts/Simhei.ttf

# %% [markdown]
# ### 显示中文的几种处理

# %%
# 第一种方法，已试，可用
import matplotlib

# 使用字体
matplotlib.rcParams['font.family'] = ['Heiti TC']

# %%
# 第二种方法，没试
plt.rcParams['font.sans-serif']=['Heiti TC'] #用来正常显示中文标签（动态设置）
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
# 获得配置文件位置
matplotlib.matplotlib_fname()
# Out:
# '/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
# 查找本地字体文件
import os

for root,_,files in os.walk('/opt'):
    for file in files:
        if file.endswith('.ttf'):
            print(root,file)
# Out:
# /opt/anaconda3/qml/QtQuick/Dialogs/qml icons.ttf
# /opt/anaconda3/pkgs/jupyterlab-1.1.4-pyhf63ae98_0/site-packages/jupyterlab/static b06871f281fee6b241d60582ae9369b9.ttf
# /opt/anaconda3/pkgs/jupyterlab-1.1.4-pyhf63ae98_0/share/jupyter/lab/static b06871f281fee6b241d60582ae9369b9.ttf
# /opt/anaconda3/pkgs/anaconda-navigator-1.9.7-py37_0/lib/python3.7/site-packages/anaconda_navigator/static/fonts Ubuntu-M.ttf
# /opt/anaconda3/pkgs/anaconda-navigator-1.9.7-py37_0/lib/python3.7/site-packages/anaconda_navigator/static/fonts Ubuntu-L.ttf
# /opt/anaconda3/pkgs/anaconda-navigator-1.9.7-py37_0/lib/python3.7/site-packages/anaconda_navigator/static/fonts UbuntuMono-BI.ttf
# /opt/anaconda3/pkgs/anaconda-navigator-1.9.7-py37_0/lib/python3.7/site-packages/anaconda_navigator/static/fonts Ubuntu-BI.ttf
# /opt/anaconda3/pkgs/anaconda-navigator-1.9.7-py37_0/lib/python3.7/site-packages/anaconda_navigator/static/fonts Ubuntu-MI.ttf
# ...

# %%
from matplotlib.font_manager import findfont, FontProperties

font = findfont(FontProperties(family=['sans-serif']))
font
# Out:
# '/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %%
# 使用本地已有字体文件
import matplotlib.font_manager

font_zh=matplotlib.font_manager.FontProperties(fname='/users/liqiang/Downloads/超清区常用字幕字体/华康少女字体.ttf')

# --- 此处为程序体 ---

plt.title('直方图数据分析与展示',fontproperties=font_zh, fontsize=15) # fontproperties参数是关键

# %%
# 查找可用字体
import matplotlib

for f in matplotlib.font_manager.fontManager.ttflist:
    if 'songti' in f.name.lower():
        print(f.name)
# Out:
# Songti SC

# %%
# 较为全面的字体设置
from matplotlib import rcParams

config = {
    "font.family": 'serif', # 衬线字体
    "font.size": 12, # 相当于小四大小
    "font.serif": ['simhei'], # 宋体
    "mathtext.fontset": 'stix', # matplotlib渲染数学字体时使用的字体，和Times New Roman差别不大
    'axes.unicode_minus': False # 处理负号，即-号
}
rcParams.update(config)

# %% [markdown]
# ### 测试区

# %%
# 使用本地已有字体文件
import matplotlib.font_manager

#font_zh=matplotlib.font_manager.FontProperties(fname='/users/liqiang/Downloads/超清区常用字幕字体/叶根友圆趣卡通简体.ttf')

# 中文处理
import matplotlib

# 使用中文字体
matplotlib.rcParams['font.family'] = ['Heiti TC']

#-------------
# 测试程序
import matplotlib.pyplot as plt

# distribution of companies with request for data analyst 
data = np.array([46,16,15,8,5,2,2,2,2,2,1,1,1]) 
ser = pd.Series(data) 
ser.index = np.array(["移动互联网","文娱","数据服务","电商","企业服务",
"教育","游戏","汽车","社交","医疗","通讯电子","广告营销","金融"]) 

ax = ser.plot('bar')
#plt.title("数据分析师-行业分布", fontdict = {'fontsize':15, 'family':'Heiti TC'}) # 可临时指定字体和大小，第一种用法
#------------

#plt.title('数据分析师-行业分布',fontproperties=font_zh, fontsize=20) # 第二种用法，fontproperties参数

plt.title('数据分析师-行业分布',fontsize=20)
ax.set_xticklabels(ser.index)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.

# %%
# 指定自定义字体显示图像
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.DataFrame({'perc': pd.Series([45, 35, 10, 5, 3, 2], index=['A', 'B', 'C','D','E','F'])})

# 指定要使用的自定义字体 specify the custom font to use
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Comic Sans MS'

fig, ax = plt.subplots(figsize=(7,4))
df.iloc[::-1].plot(kind='barh', legend = False, ax=ax) # 直接调用pandas.plot(), 'barh'为水平条形图
ax.set_xlabel('Percentage',fontsize=15)
ax.set_ylabel('Type',fontsize=15)
# Out:
# Text(0, 0.5, 'Type')

# %%
df
# Out:
#    perc
# A    45
# B    35
# C    10
# D     5
# E     3
# F     2

# %% [markdown]
# ### matplotlib基础

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ### 基础语句

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5])

plt.plot(ypoints, marker = 'o', linestyle = 'dotted')

plt.rcParams['font.family'] = 'Heiti TC'

# 创建标签
plt.title("这是一个例子", fontsize=22)
plt.xlabel("这是X轴", fontsize=12)
plt.ylabel("这是Y轴", fontsize=12)

# 显示网格线
# plt.grid()

plt.show()

# %% [markdown]
# ### 显示多个图

# %%
# 使用subplot()显示多张图
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 3, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 3, 2)
plt.plot(x,y)

#plot 3:
ypoints = np.array([3, 8, 1, 10, 5])
plt.subplot(1, 3, 3)
plt.plot(ypoints, marker = 'o', linestyle = 'dotted')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)


t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), color='tab:blue', marker='o')
plt.plot(t2, f(t2), color='black')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), color='tab:orange', linestyle='--')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ### 散点图

# %%
# 用scatter()绘制散点图
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### 条形图

# %%
# 用bar()创建条形图
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# ### 直方图

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ### 饼图

# %%
# 基础图，pie()函数画饼
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
# 加入标签
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"] # 标签数组
myexplode = [0.1, 0, 0, 0] # 分离
mycolors = ["black", "hotpink", "b", "#4CAF50"] # 颜色

plt.pie(y, labels = mylabels, labeldistance=1.1, startangle = 0, 
        explode = myexplode, shadow = False,
       colors = None) # 注意labels和startangle

#plt.legend(title = "水果:", loc=1,bbox_to_anchor=(1, 0.6, 0.5, 0.5), borderaxespad=0) # bbox_to_anchor参数对legend位置的影响更直接

plt.legend(title = "水果:", loc=1, bbox_to_anchor=(1, 0.6), borderaxespad=-7)

plt.show()

# %% [markdown]
# ### 把legend放到框外

# %%
import pandas as pd
import matplotlib.pyplot as plt

#create data
df = pd.DataFrame({'points': [11, 17, 16, 18, 22, 25, 26, 24, 29],
                   'assists': [5, 7, 7, 9, 12, 9, 9, 4, 8]})

#add lines to plot
plt.plot(df['points'], label='Points', color='green')
plt.plot(df['assists'], label='Assists', color='steelblue')

#place legend in center right of plot
plt.legend(bbox_to_anchor=(1.02, 0.17), loc='upper left', borderaxespad=0)

# %% [markdown]
# ### legend位置说明

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

upper_left = mpatches.Patch(color='red', label='upper left')
upper_right = mpatches.Patch(color='blue', label='upper right')
lower_right = mpatches.Patch(color='purple', label='lower right')
lower_left = mpatches.Patch(color='yellow', label='lower left')
center_left = mpatches.Patch(color='green', label='center left')
center_right = mpatches.Patch(color='gray', label='center right')
lower_center = mpatches.Patch(color='black', label='lower center')
upper_center = mpatches.Patch(color='green', label='upper center')
center = mpatches.Patch(color='purple', label='center')


patches = [upper_left, upper_right, lower_left, lower_right, center_left, center_right, lower_center, 
           upper_center,center]

location = ['upper left', 'upper right', 'lower left', 'lower right', 'center left', 'center right',
           'lower center', 'upper center', 'center']

lst = []
fig, ax = plt.subplots(figsize=(16, 9))
for patch, loc in zip(patches, location):
    lst.append(ax.legend(handles=[patch], loc=loc, fontsize=18))
    
for i in range(len(patches)):
    plt.gca().add_artist(lst[i])
    
ax.annotate('borderaxespad', xy=(0.1, 0.99), xytext=(0.2, 0.8), fontsize=18,
            arrowprops={'arrowstyle':'->'})
ax.annotate('', xy=(0.001, 0.5), xytext=(0.25, 0.8), fontsize=18,arrowprops={'arrowstyle':'->'})

ax.set_title('loc-str类型参数图示', fontsize=18, fontweight='bold')
ax.tick_params(labelsize=14)
# 至于那些缝隙，可以通过设置borderaxespad=0消除

# %% [markdown]
# ## 美丽的条形图

# %% [markdown]
# ### 准备

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

# set the style of the axes and the text color
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['text.color']='#333F4B'

# %%
# create some fake data
percentages = pd.Series([20, 15, 18, 8, 6, 7, 10, 2, 10, 4], 
                        index=['Rent', 'Transportation', 'Bills', 'Food', 
                               'Travel', 'Entertainment', 'Health', 'Other', 'Clothes', 'Phone'])
df = pd.DataFrame({'percentage' : percentages})
df = df.sort_values(by='percentage')

# %% [markdown]
# ### 第一种 条形图 Matplotlib bar chart

# %%
fig, ax = plt.subplots(figsize=(7,4))
df.plot(kind='barh', legend = False, ax=ax)
ax.set_xlabel('Percentage')
ax.set_ylabel('Transaction Type')
plt.savefig('hist1.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### 第二种 我们自己的条形图

# %%
# we first need a numeric placeholder for the y axis
my_range=list(range(1,len(df.index)+1))

fig, ax = plt.subplots(figsize=(5,3.5))

# create for each expense type an horizontal line that starts at x = 0 with the length 
# represented by the specific expense percentage value.
plt.hlines(y=my_range, xmin=0, xmax=df['percentage'], color='#007ACC', alpha=0.2, linewidth=5)

# create for each expense type a dot at the level of the expense percentage value
plt.plot(df['percentage'], my_range, "o", markersize=5, color='#007ACC', alpha=0.6)

# set labels
ax.set_xlabel('Percentage', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('')

# set axis
ax.tick_params(axis='both', which='major', labelsize=12)
plt.yticks(my_range, df.index)

# add an horizonal label for the y axis 
fig.text(-0.23, 0.96, 'Transaction Type', fontsize=15, fontweight='black', color = '#333F4B')

# change the style of the axis spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['left'].set_bounds(1, len(my_range))
ax.set_xlim(0,25)

ax.spines['left'].set_position(('outward', 8))
ax.spines['bottom'].set_position(('outward', 5))

plt.savefig('hist2.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### 第三种 更炫的

# %%
df = df.sort_values(by='percentage', ascending=False)
my_range=list(range(1,len(df.index)+1))

fig, ax = plt.subplots(figsize=(4.5,3))
plt.vlines(x=my_range, ymin=0, ymax=df['percentage'], color='#FF005C', alpha=0.2, linewidth=5)
plt.plot(my_range, df['percentage'], "o", markersize=5, color='#FF005C', alpha=0.6)

ax.set_xlabel('Transaction Type', fontsize=15, fontweight='black', color = '#333F4B')
ax.tick_params(axis='both', which='major', labelsize=12)

ax.set_ylabel('Percentage', fontsize=15, fontweight='black', color = '#333F4B')

# change the style of the axis spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['left'].set_bounds(0, 20)
ax.spines['bottom'].set_bounds(1, len(my_range))

ax.spines['left'].set_position(('outward', 8))
ax.spines['bottom'].set_position(('outward', 5))

plt.xticks(my_range, df.index, rotation=45, ha='right')

plt.savefig('hist3.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 使用 Pandas Plot 在 Python 中制作更好的条形图

# %% [markdown]
# ### 环境准备

# %%
# 设置图形大小 Set the figure size - handy for larger output
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10, 6]
# 设置更高的分辨率，这对Mac很有效 Set up with a higher resolution screen (useful on Mac)
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### 入门

# %%
# 导入标准库 Import the pandas library with the usual "pd" shortcut
import pandas as pd
# 建立一个简单的序列并画出来 Create a Pandas series from a list of values ("[]") and plot it:
pd.Series([65, 61, 25, 22, 27]).plot(kind="bar")

# %%
# 也可以创建一个数据框 Create a data frame with one column, "ages"
# 第一种方法，已试，可用
import matplotlib

# 使用字体
matplotlib.rcParams['font.family'] = ['Heiti TC']

plotdata = pd.DataFrame({"年龄": [65, 61, 25, 22, 27]})
plotdata.plot(kind="bar")

# %% [markdown]
# ### 标签

# %%
# 为数据框指定索引 Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"pies": [10, 10, 42, 17, 37]}, 
    #index=["爸爸", "妈妈", "哥哥", "姐姐", "我"])
    index=["Dad", "Mam", "Bro", "Sis", "Me"])
# 绘制条形图 Plot a bar chart
plotdata.plot(kind="bar")

'''
以下语句与上面结果相同，主要是由于本数据框只有一列，真实数据不太会出现这样的情况。
plotdata['pies'].plot(kind="bar")
'''
# Out:
# '\n以下语句与上面结果相同，主要是由于本数据框只有一列，真实数据不太会出现这样的情况。\nplotdata[\'pies\'].plot(kind="bar")\n'

# %% [markdown]
# ### 标记轴并添加绘图标题

# %% [markdown]
# - “xlabel” 添加一个x轴标签
# - “ylabel” 添加一个y轴标签
# - “标题” 添加情节标题

# %%
from matplotlib import pyplot as plt
plotdata['pies'].plot(kind="bar", title="test")

plt.title("Mince Pie Consumption Study Results")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# ### 旋转 x 轴标签

# %% [markdown]
# 使用Matplotlib的xticks函数，它带有：
#
# - rotation
# - horizontalalignment
#
# 两个参数负责处理旋转

# %%
plotdata['pies'].plot(kind="bar", title="test")

# 将x-label旋转30度，并保持文本水平对齐 Rotate the x-labels by 30 degrees, and keep the text aligned horizontally
plt.xticks(rotation=30, horizontalalignment="center")

plt.title("Mince Pie Consumption Study Results")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# ### 水平条形图

# %%
plotdata['pies'].plot(kind="barh") # barh为水平

plt.title("Mince Pie Consumption Study Results")
plt.ylabel("Family Member")
plt.xlabel("Pies Consumed")
# Out:
# Text(0.5, 0, 'Pies Consumed')

# %% [markdown]
# ### 附加系列：堆叠和非堆叠条形图

# %%
# Create a DataFrame with 3 columns:
plotdata = pd.DataFrame({
    "pies_2018":[40, 12, 10, 26, 36],
    "pies_2019":[19, 8, 30, 21, 38],
    "pies_2020":[10, 10, 42, 17, 37]
    }, 
    index=["Dad", "Mam", "Bro", "Sis", "Me"]
)
plotdata.head()
# Out:
#      pies_2018  pies_2019  pies_2020
# Dad         40         19         10
# Mam         12          8         10
# Bro         10         30         42
# Sis         26         21         17
# Me          36         38         37

# %% [markdown]
# #### 未堆叠的条形图

# %%
plotdata = pd.DataFrame({
    "pies_2018":[40, 12, 10, 26, 36],
    "pies_2019":[19, 8, 30, 21, 38],
    "pies_2020":[10, 10, 42, 17, 37]
    }, 
    index=["Dad", "Mam", "Bro", "Sis", "Me"]
)

plotdata.plot(kind="bar")

plt.title("Mince Pie Consumption Study")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %%
#### 叠加条形图 Stacked bar plots

# %%
# 在plot()函数中增加stacked=True参数设置 Adding the stacked=True option to plot() 
# 以创建一个叠加条形图 creates a stacked bar plot

plotdata.plot(kind='bar', stacked=True)

plt.title("Total Pie Consumption")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# #### 按顺序选择叠加 Ordering stacked and unstacked bars

# %%
# 按顺序选择叠加 Choose columns in the order to "stack" them

plotdata[["pies_2020", "pies_2018", "pies_2019"]].plot(kind="bar", stacked=True)

plt.title("Mince Pie Consumption Totals")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# #### 按百分比叠加 Stacking to 100% (filled-bar chart)

# %%
plotdata = pd.DataFrame({
    "pies_2018":[40, 12, 10, 26, 36],
    "pies_2019":[19, 8, 30, 21, 38],
    "pies_2020":[10, 10, 42, 17, 37]
    }, index=["Dad", "Mam", "Bro", "Sis", "Me"]
)
plotdata.head()
# Out:
#      pies_2018  pies_2019  pies_2020
# Dad         40         19         10
# Mam         12          8         10
# Bro         10         30         42
# Sis         26         21         17
# Me          36         38         37

# %%
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)

stacked_data.plot(kind="bar", stacked=True)

plt.title("Mince Pie Consumption Breakdown")
plt.xlabel("Family Member")
plt.ylabel("Percentage Pies Consumed (%)")
# Out:
# Text(0, 0.5, 'Percentage Pies Consumed (%)')

# %% [markdown]
# #### 转置以获得不同的视图

# %%
# 使用transpose()函数进行转置
plotdata.transpose().apply(lambda x: x*100/sum(x), axis=1).plot(kind="bar", stacked=True)

plt.title("Mince Pie Consumption Per Year")
plt.xlabel("Year")
plt.ylabel("Pies Consumed (%)")
# Out:
# Text(0, 0.5, 'Pies Consumed (%)')

# %% [markdown]
# #### 手动选择 X 轴

# %%
# 重置索引
plotdata.reset_index().plot(
    x="index", y=["pies_2018", "pies_2019"], kind="bar"
)

plt.title("Mince Pie Consumption 18/19")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %%
plotdata.reset_index()
# Out:
#   index  pies_2018  pies_2019  pies_2020
# 0   Dad         40         19         10
# 1   Mam         12          8         10
# 2   Bro         10         30         42
# 3   Sis         26         21         17
# 4    Me         36         38         37

# %% [markdown]
# ### 按类别着色

# %% [markdown]
# #### 手动着色

# %%
# 为数据框指定索引 Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"pies": [10, 10, 42, 17, 37]}, 
    index=["Dad", "Mam", "Bro", "Sis", "Me"])

# %%
plotdata['pies'].plot(kind="bar", color=['black', 'red', 'black', 'red', 'black'])

# %%
#### 按列着色 Colouring by a column

# %%
plotdata = pd.DataFrame({
    "pies": [10, 10, 42, 17, 37], 
    "gender": ["male", "female", "male", "female", "male"]
    }, 
    index=["Dad", "Mam", "Bro", "Sis", "Me"]
)
plotdata.head()
# Out:
#      pies  gender
# Dad    10    male
# Mam    10  female
# Bro    42    male
# Sis    17  female
# Me     37    male

# %% [markdown]
# - words (“red”, “black”, “blue” etc.),
# - RGB hex codes (“#0097e6”, “#7f8fa6”), or
# - with single-character shortcuts from matplotlib (“k”, “r”, “b”, “y” etc).

# %%
# 定义一个字典，将变量值映射到颜色上 Define a dictionary mapping variable values to colours:

colours = {"male": "#273c75", "female": "#44bd32"}

plotdata['pies'].plot(
    kind="bar", 
    color=plotdata['gender'].replace(colours)
)

# %% [markdown]
# #### 为手动彩色条添加图例

# %%
from matplotlib.patches import Patch

colours = {"male": "#273c75", "female": "#44bd32"}

plotdata['pies'].plot(
        kind="bar", color=plotdata['gender'].replace(colours)
).legend(
    [
        Patch(facecolor=colours['male']),
        Patch(facecolor=colours['female'])
    ], ["male", "female"]
)

plt.title("Mince Pie Consumption")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# ### 为您的 Pandas 条形图设计样式

# %% [markdown]
# #### 微调你的情节图例——位置和隐藏

# %%
plotdata = pd.DataFrame({
    "pies_2018":[40, 12, 10, 26, 36],
    "pies_2019":[19, 8, 30, 21, 38],
    "pies_2020":[10, 10, 42, 17, 37]
    }, index=["Dad", "Mam", "Bro", "Sis", "Me"]
)
plotdata.head()
# Out:
#      pies_2018  pies_2019  pies_2020
# Dad         40         19         10
# Mam         12          8         10
# Bro         10         30         42
# Sis         26         21         17
# Me          36         38         37

# %%
# 你可以通过legend=False参数快速关闭图例
plotdata[["pies_2020", "pies_2018", "pies_2019"]].plot(
    kind="bar", stacked=True, legend=False
)

# %% [markdown]
# - best
# - upper right
# - upper left
# - lower left
# - lower right
# - right
# - center left
# - center right
# - lower center
# - upper center
# - center

# %%
# 使用legend()绘制和控制图例位置、布局和标题 Plot and control the legend position, layout, and title with .legend(...)
plotdata[["pies_2020", "pies_2018", "pies_2019"]].plot(
    kind="bar", stacked=True
).legend(
    loc='upper center', ncol=3, title="Year of Eating"
)

plt.title("Mince Pie Consumption Totals")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# ### 应用主题和样式

# %% [markdown]
# #### 使用 Matplotlib 主题

# %% [markdown]
# Matplotlib内置主题列表前点击[这里](https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html)

# %%
import matplotlib

# 使用Matplotlib内置主题
matplotlib.style.use('Solarize_Light2')

plotdata.plot(kind="bar")

plt.title("Mince Pie Consumption by 538")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# #### 使用Seaborn

# %%
import seaborn as sns

sns.set_style("dark")

plotdata.plot(kind="bar")

plt.title("Mince Pie Consumption in Seaborn style")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')

# %% [markdown]
# ### Word Cloud

# %%
# 标准库
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
titanic.loc[titanic['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 用泰坦尼克数据提取乘客名字
titanic = pd.read_csv('http://bit.ly/kaggletrain')
titanic.head()
names = ' '.join(name[0] for name in titanic.loc[titanic['Survived'] == 0].Name.str.split(','))

# %%
# 创建并生成词云图像 Create and generate a word cloud image:
wordcloud = WordCloud().generate(names)

# %%
# 显示所生成的图像 Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# 调整字体大小，改变最大字数，淡化背景 lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(names)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# 保存文件 Save the image in the img folder:
wordcloud.to_file("desktop/first_review.png")

# %%
from PIL import Image

titanic_mask = np.array(Image.open("desktop/alice.png")) # twitter_mask.png

# %%
# Create a word cloud image
wc = WordCloud(background_color="white", max_words=100, mask=titanic_mask,
               contour_width=0, contour_color='firebrick') # contour_width可以显示轮廓实线

# Generate a wordcloud
wc.generate(names)

# store to file
wc.to_file("desktop/titanic_out.png")

# show
#plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# 加载维基百科库
import wikipedia

# %%
#encoding:utf-8

wikipedia.set_lang("zh") #设置语言

# %%
# 获取页面内容 Fetching the page content
result= wikipedia.page("梁思成")
final_result = result.content
print(final_result)
# Out:
# 梁思成（1901年4月20日－1972年1月9日），籍贯广东新会，生于日本东京，男，中國建築史學家、建築師、城市規劃師、教育家，一生致力於保護中國古代建築和文化遺產。曾任中央研究院院士、中國科學院哲學社會科學學部委員。在《建筑五宗师》书中与吕彦直、刘敦桢、童寯、杨廷宝合称“建筑五宗师”。
#
#
# == 生平 ==
#
#
# === 成長求學時期 ===
# 梁思成的父親梁啟超是清朝著名的政治家，曾發動戊戌變法，為躲避慈禧太后迫害而流亡海外，所以梁思成出生於日本東京，1912年辛亥革命後，隨父母從日本回國，曾在北京崇德國小及匯文中學就學。1915年入北平清華學校（1928年之後的清華大學），1923年畢業於清華學校高等科。1924年和林徽因一起赴美國費城宾夕法尼亚大學建築系學習，1927年獲得學士和碩士學位，又去哈佛大學學習建築史，研究中國古代建築（未毕业）。在求學期間，因為其父梁啟超和未婚妻林徽因的關係，結識了徐志摩。雖然爾後因徐志摩對林徽因抱持好感而略有嫌隙，但是日後得知徐志摩在趕往想要聽他與林徽因的演講發生空難身亡，仍然為徐志摩哀傷。
# 1928年与林徽因在渥太华結婚後赴歐洲考察各地建築，回國後在瀋陽東北大學（张学良时任校长）任教，在那裡創立了中國現代教育史上第一個建築學系。同時成立了建築師事務所，設計建造了東北大學主樓，並測量考察了清昭陵的建築，當時就試圖保護瀋陽鐘鼓樓，但不被當地政府採納，終於被拆毀。1930年和張銳參與天津市規劃，以《天津特别市物质建设方案》獲獎。
#
#
# === 抗日戰爭時期 ===
# 日本侵略東北後，梁思成於1931年回到北平，進入中國營造學社工作，梁思成入营造学社后的第一件工作，就是在1932年主持故宫文渊阁的修复工程。
# 梁思成原计划即时著手研究宋代《營造法式》，不料「這部漂亮精美的巨著，竟如天書一樣，無法看得懂」。為了深入研究古代，他首先從比較近的《清工部工程做法则例》著手，拜北京老木匠和彩畫匠為師，配合研究北平大量清代建築，搞懂《清工部工程作法則例》，在1932年著成《清式營造則例》手稿（1934年出版）。
# ...

# %%
import jieba

seg_list = jieba.cut(final_result, cut_all=False)
names = ' '.join(name for name in seg_list)
names = names.replace('中国 银 保监会','中国银保监会')
names = names.replace('杭州市 中 北 二小','杭州市中北二小')
names = names.replace('馬 雲','馬雲')
names = names.replace('馬 化騰','馬化騰')
names = names.replace('蚂蚁 集团','蚂蚁集团')
names = names.replace('邓小平','鄧小平')
names = names.replace('趙 又 廷','趙又廷')
names = names.replace('射雕 英雄传','射雕英雄傳')
names = names.replace('神 鵰 俠侶','神鵰俠侶')
names = names.replace('倚天 屠龍記','倚天屠龍記')
names = names.replace('天龍 八部','天龍八部')
names = names.replace('射雕 英雄 傳','射雕英雄傳')
names = names.replace('射鵰 英雄 傳','射雕英雄傳')
names = names.replace('碧血 劍','碧血劍')
names = names.replace('射 鵰','射鵰')
names = names.replace('人间 四月 天','人间四月天')
names = names.replace('飛雪連 天射 白鹿','飛雪連天射白鹿')
names = names.replace('笑書 神俠 倚 碧 鴛','笑書神俠倚碧鴛')
print(names)
# Out:
# 梁思成 （ 1901 年 4 月 20 日 － 1972 年 1 月 9 日 ） ， 籍贯 广东 新 会 ， 生于 日本 东京 ， 男 ， 中國 建築史 學家 、 建築師 、 城市 規劃師 、 教育家 ， 一生 致力 於 保護 中國 古代 建築 和 文化 遺產 。 曾任 中央研究院 院士 、 中國 科學院 哲學 社會 科學學 部委 員 。 在 《 建筑 五 宗师 》 书中 与 吕彦直 、 刘敦桢 、 童 寯 、 杨廷宝 合称 “ 建筑 五 宗师 ” 。
#
#
#  = =   生平   = =
#
#
#  = = =   成長 求學 時期   = = =
#  梁思成 的 父親 梁啟 超是 清朝 著名 的 政治家 ， 曾 發動 戊戌 變法 ， 為 躲避 慈禧太后 迫害 而 流亡海外 ， 所以 梁思成 出生 於 日本 東京 ， 1912 年 辛亥革命 後 ， 隨 父母 從 日本 回國 ， 曾 在 北京 崇德 國小及 匯 文中 學就學 。 1915 年入 北平 清華學校 （ 1928 年 之 後 的 清華大學 ） ， 1923 年 畢業 於 清華學校 高等 科 。 1924 年 和 林徽因 一起 赴美 國費城 宾夕法尼亚 大學 建築系 學習 ， 1927 年 獲得 學士 和 碩士 學位 ， 又 去 哈佛 大學學習 建築史 ， 研究 中國 古代 建築 （ 未 毕业 ） 。 在 求學 期間 ， 因為 其父 梁啟 超 和 未婚妻 林徽因 的關 係 ， 結識 了 徐志摩 。 雖然爾後因 徐志摩 對 林徽因 抱持 好感 而 略有 嫌隙 ， 但是 日 後 得知 徐志摩 在 趕往 想要 聽 他 與 林徽因 的 演講 發生 空難 身亡 ， 仍然 為 徐志摩 哀傷 。
# ...

# %%
from PIL import Image

titanic_mask = np.array(Image.open("desktop/axe.jpeg")) # twitter_mask.png

# 设置更高的分辨率，这对Mac很有效 Set up with a higher resolution screen (useful on Mac)
# %config InlineBackend.figure_format = 'retina'

# %%
# Create a word cloud image

# 设置停用词
stopwords = set(STOPWORDS)
stopwords = mystopwords
wc = WordCloud(font_path='/users/liqiang/Library/Fonts/Simhei.ttf',background_color="black", max_words=100, mask=titanic_mask,
               stopwords=stopwords, contour_width=0, contour_color='firebrick') # contour_width可以显示轮廓实线

# Generate a wordcloud
wc.generate(names)

# store to file
wc.to_file("desktop/titanic_out.png")

# show
#plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# 查询维基百科库可用语言
print(wikipedia.languages())

# %%
my_stop_words = ["、","。","〈","〉","《","》","一","一切","一则","一方面","一旦","一来","一样","一般","七","万一","三","上下","不仅","不但","不光","不单","不只","不如","不怕","不惟","不成","不拘","不比","不然","不特","不独","不管","不论","不过","不问","与","与其","与否","与此同时","且","两者","个","临","为","为了","为什么","为何","为着","乃","乃至","么","之","之一","之所以","之类","乌乎","乎","乘","九","也","也好","也罢","了","二","于","于是","于是乎","云云","五","人家","什么","什么样","从","从而","他","他人","他们","以","以便","以免","以及","以至","以至于","以致","们","任","任何","任凭","似的","但","但是","何","何况","何处","何时","作为","你","你们","使得","例如","依","依照","俺","俺们","倘","倘使","倘或","倘然","倘若","借","假使","假如","假若","像","八","六","兮","关于","其","其一","其中","其二","其他","其余","其它","其次","具体地说","具体说来","再者","再说","冒","冲","况且","几","几时","凭","凭借","则","别","别的","别说","到","前后","前者","加之","即","即令","即使","即便","即或","即若","又","及","及其","及至","反之","反过来","反过来说","另","另一方面","另外","只是","只有","只要","只限","叫","叮咚","可","可以","可是","可见","各","各个","各位","各种","各自","同","同时","向","向着","吓","吗","否则","吧","吧哒","吱","呀","呃","呕","呗","呜","呜呼","呢","呵","呸","呼哧","咋","和","咚","咦","咱","咱们","咳","哇","哈","哈哈","哉","哎","哎呀","哎哟","哗","哟","哦","哩","哪","哪个","哪些","哪儿","哪天","哪年","哪怕","哪样","哪边","哪里","哼","哼唷","唉","啊","啐","啥","啦","啪达","喂","喏","喔唷","嗡嗡","嗬","嗯","嗳","嘎","嘎登","嘘","嘛","嘻","嘿","四","因","因为","因此","因而","固然","在","在下","地","多","多少","她","她们","如","如上所述","如何","如其","如果","如此","如若","宁","宁可","宁愿","宁肯","它","它们","对","对于","将","尔后","尚且","就","就是","就是说","尽","尽管","岂但","己","并","并且","开外","开始","归","当","当着","彼","彼此","往","待","得","怎","怎么","怎么办","怎么样","怎样","总之","总的来看","总的来说","总的说来","总而言之","恰恰相反","您","慢说","我","我们","或","或是","或者","所","所以","打","把","抑或","拿","按","按照","换句话说","换言之","据","接着","故","故此","旁人","无宁","无论","既","既是","既然","时候","是","是的","替","有","有些","有关","有的","望","朝","朝着","本","本着","来","来着","极了","果然","果真","某","某个","某些","根据","正如","此","此外","此间","毋宁","每","每当","比","比如","比方","沿","沿着","漫说","焉","然则","然后","然而","照","照着","甚么","甚而","甚至","用","由","由于","由此可见","的","的话","相对而言","省得","着","着呢","矣","离","第","等","等等","管","紧接着","纵","纵令","纵使","纵然","经","经过","结果","给","继而","综上所述","罢了","者","而","而且","而况","而外","而已","而是","而言","能","腾","自","自个儿","自从","自各儿","自家","自己","自身","至","至于","若","若是","若非","莫若","虽","虽则","虽然","虽说","被","要","要不","要不是","要不然","要么","要是","让","论","设使","设若","该","诸位","谁","谁知","赶","起","起见","趁","趁着","越是","跟","较","较之","边","过","还是","还有","这","这个","这么","这么些","这么样","这么点儿","这些","这会儿","这儿","这就是说","这时","这样","这边","这里","进而","连","连同","通过","遵照","那","那个","那么","那么些","那么样","那些","那会儿","那儿","那时","那样","那边","那里","鄙人","鉴于","阿","除","除了","除此之外","除非","随","随着","零","非但","非徒","靠","顺","顺着","首先","︿","！","＃","＄","％","＆","（","）","＊","＋","，","０","１","２","３","４","５","６","７","８","９","：","；","＜","＞","？","＠","［","］","｛","｜","｝","～","￥"]

# %%
mystopwords = my_stop_words + list("把 下 没 更 生活 以及 新 一次 指出 之 任 其 多 及 個 存档 可能 六四 同时 三年 曾 超过 数学 人物 又 文化 社會 社会 网站 提出 要求 成果 成功 个人 这些 人民币 时间 其中 今天 自己 大学 與 成立 受到 現 人民 考了 分 工商 後 开始 没 没有 表示 网 对 亿元 还是 同年 發展 借 說 以 发展 说 决定 引發 引发 為 會 還是 時間 以上 事件 股份 由 首次 對 成為 成为 但 能 很 这 时 于 不 电子 来 來 集团 集團 由於 由于 亿 億 中 作為 作为 进行 有人 为 包括 认为 参加 元 利用 造成 名字 他 她 年 月 日 了 上 也 和 广告 在 中国 人 因 都 后 的 与 而 被 做 员工 有 一个 不是 是 我 将 还 最 有限公司 等 要 工作 參加 時間 你".split())

# %%
msw.append('巷')

# %%
msw
# Out:
# ['跟',
#  '沿着',
#  '而是',
#  '然则',
#  '可见',
#  '那个',
#  '趁',
#  '咋',
#  '、',
#  '任',
#  '别说',
#  '成功',
#  '考了',
#  '呕',
#  '不怕',
#  '呸',
#  '咦',
#  '俺',
#  '所',
#  '借',
#  '人物',
#  '时候',
#  '到',
#  '你',
#  '鄙人',
#  '同',
#  '恰恰相反',
#  '不如',
#  '只是',
#  '电子',
#  '至于',
#  '通过',
#  '月',
#  '既',
#  '么',
#  '己',
#  '一样',
#  '都',
#  '加之',
#  '毋宁',
#  '顺',
#  '起见',
#  '其一',
#  '比',
#  '咚',
#  '着呢',
#  '成為',
#  '朝',
#  '与其',
#  '但',
#  '不光',
#  '即令',
#  '与此同时',
#  '哪年',
#  '１',
#  '超过',
#  '冒',
#  '用',
#  '者',
#  '临',
#  '还有',
#  '乘',
#  '这么',
#  '能',
#  '旁人',
#  '我',
#  '就',
#  '要是',
#  '如此',
#  '为何',
#  '与否',
#  '这就是说',
#  '后',
#  '今天',
#  '一旦',
#  '倘若',
#  '》',
#  '咱',
#  '啊',
#  '俺们',
#  '唉',
#  '以上',
#  '￥',
#  '除',
#  '省得',
#  '赶',
#  '有些',
#  '二',
#  '并且',
#  '＋',
#  '所以',
#  '于是',
#  '吗',
#  '依',
#  '吧哒',
#  '人民',
#  '引发',
#  '纵使',
#  '其它',
#  '有限公司',
#  '七',
#  '同时',
#  '设若',
#  '广告',
#  '同年',
#  '照',
#  '即',
#  '具体地说',
#  '兮',
#  '着',
#  '哩',
#  '反之',
#  '存档',
#  '矣',
#  '较之',
# ...

# %%
mystopwords = list(set(msw))

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import urllib
import requests
import numpy as np
import matplotlib.pyplot as plt

words = 'access guest guest apartment area area bathroom bed bed bed bed bed bedroom block coffee coffee coffee coffee entrance entry francisco free garden guest home house kettle kettle kitchen kitchen kitchen kitchen kitchen kitchenliving located microwave neighborhood new park parking place privacy private queen room san separate seperate shared space space space street suite time welcome'
mask = np.array(Image.open(requests.get('http://www.clker.com/cliparts/O/i/x/Y/q/P/yellow-house-hi.png', stream=True).raw))

# This function takes in your text and your mask and generates a wordcloud. 
def generate_wordcloud(words, mask):
    word_cloud = WordCloud(font_path='/users/liqiang/Library/Fonts/Simhei.ttf', width = 512, height = 512, background_color='white', stopwords=mystopwords, mask=mask).generate(names)
    plt.figure(figsize=(6,6),facecolor = 'white', edgecolor='blue')
    plt.imshow(word_cloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    
#Run the following to generate your wordcloud
generate_wordcloud(words, mask)

# %% [markdown]
# #### 中文圈里的常见写法

# %%
# 设置停用词
stopwords = set(STOPWORDS)
stopwords.add("")

# 设置词云形状
wc = WordCloud(font_path='simhei.ttf', width=800, height= 600, background_color="white", max_words=300, mask=my_coloring,
               stopwords=stopwords, max_font_size=110, random_state=200)
# 运行统计
wc.generate(text)

# 获取color
image_colors = ImageColorGenerator(my_coloring)

# 展示
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.figure()
wc.to_file(file+'_1.png')

# %% [markdown]
# ### 未核实

# %%
# 未核实，待用

# 设置中文字体
import matplotlib

# 指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['Songti SC']
matplotlib.rcParams['font.family'] ='sans-serif'

# 解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False
    
#--------------

# 单个字体文件
from matplotlib import font_manager

font_manager.fontManager.addfont("/fonts/ipag.ttf") # 报错，addfont不存在
matplotlib.rc('font', family="IPAGothic")

#-------------

# 多个字体文件
from matplotlib import font_manager

font_files = font_manager.findSystemFonts(fontpaths=["/fonts"])

for font_file in font_files:
    font_manager.fontManager.addfont(font_file) # 报错，addfont不存在

matplotlib.rc('font', family="IPAGothic")

#-------------

# 批量添加自定义字体
from matplotlib import font_manager

font_dirs = ['path/to/font/']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file) # addfont()函数未定义？！！！

# set font
plt.rcParams['font.family'] = 'Comic Sans'
